# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.neighbors import NearestNeighbors

# %%
df = pd.read_csv('../data/csv/track_vectors_1.csv', index_col=0)
df
# Out:
#           track    1_mfcc_1    1_mfcc_2   1_mfcc_3   1_mfcc_4   1_mfcc_5  \
# 0    061010.mp3 -724.060181  174.672104 -22.694757   5.049683 -10.285789
# 1    061172.mp3 -692.448303  117.801537  18.185888   5.736947   5.938968
# 2    061589.mp3 -697.955811  112.710243  80.530632  18.408318  16.321367
# 3    061493.mp3 -630.083130  135.834732 -17.474176  36.666378  20.877747
# 4    061492.mp3 -692.294617  154.660141  -3.271099  31.385326  22.588284
# ..          ...         ...         ...        ...        ...        ...
# 995  012654.mp3 -565.080444   84.677483   2.182471  32.444984   8.590429
# 996  012059.mp3 -662.046570  162.200394   1.865227   2.512091 -17.209513
# 997  012052.mp3 -681.049866  203.675125 -21.857754  20.952673  -6.320728
# 998  012353.mp3 -686.782349  156.051804 -11.043566  38.633003  -2.135220
# 999  012490.mp3 -659.320190  175.843704 -53.868198  19.394485 -11.813598
#
#       1_mfcc_6   1_mfcc_7   1_mfcc_8   1_mfcc_9  ...  all_ss_min  all_ss_std  \
# 0    -7.565227 -17.961994  -1.329323 -13.898221  ...    0.737701    0.991601
# 1    31.851004   1.060427   4.214683  -0.146251  ...   -0.198049    0.948205
# 2    33.912514  -1.067550  19.436161   2.497976  ...   -0.194649    0.554220
# 3     3.231712   0.163455  -4.143034  -7.589878  ...    0.461225    0.344698
# 4     4.178376  -0.790970  -4.321088  -4.325193  ...    0.710971    0.538033
# ..         ...        ...        ...        ...  ...         ...         ...
# 995  20.899466   6.153193  10.118557  -0.514558  ...    0.596255    0.351094
# 996   2.441982  -0.354951  -5.266220 -14.135563  ...    1.036727    0.871607
# 997   6.191135  -6.722731 -15.490950  -0.760553  ...    1.157692    1.001936
# 998   5.057468   1.721527  -3.673901  -2.122458  ...    0.214764    0.530753
# 999  -6.810745   3.778600  -9.063823 -16.290493  ...    0.391960    0.727393
#
#      all_sf_max  all_sf_mean  all_sf_min  all_sf_std  all_zcr_max  \
# 0      0.240276     0.041676    0.008984    0.031454     0.108398
# 1      0.390652     0.080923    0.000357    0.059621     0.351562
# 2      0.488206     0.133584    0.017999    0.079505     0.125000
# 3      0.404520     0.101769    0.022331    0.065322     0.267090
# 4      0.420857     0.083492    0.010698    0.055768     0.450195
# ..          ...          ...         ...         ...          ...
# 995    0.317342     0.105405    0.000469    0.041556     0.152344
# 996    0.288262     0.073833    0.018952    0.039783     0.092773
# 997    0.222403     0.068779    0.010354    0.033468     0.063965
# 998    0.189971     0.078697    0.000152    0.028348     0.130371
# 999    0.241914     0.088993    0.026514    0.031786     0.088867
#
#      all_zcr_mean  all_zcr_min  all_zcr_std
# 0        0.029397     0.009277     0.014918
# 1        0.068662     0.002930     0.058827
# 2        0.028202     0.000977     0.020876
# 3        0.083095     0.006348     0.036801
# 4        0.098991     0.005859     0.067057
# ..            ...          ...          ...
# 995      0.065887     0.004883     0.030822
# 996      0.033207     0.010254     0.012029
# 997      0.026695     0.007324     0.010179
# 998      0.043356     0.010254     0.017022
# 999      0.040983     0.005371     0.012530
#
# [1000 rows x 338 columns]

# %%
features = StandardScaler().fit_transform(df.drop(['track'], 1))
features
# Out:
# array([[-0.31871479,  0.39467434, -0.66056399, ..., -0.70779065,
#          0.59364362, -0.65562626],
#        [ 0.01244368, -0.61958969,  0.50178629, ...,  0.64830687,
#         -0.4339685 ,  1.39460041],
#        [-0.04525165, -0.71039089,  2.27442048, ..., -0.74905581,
#         -0.75015685, -0.37742391],
#        ...,
#        [ 0.13185098,  0.91193173, -0.63676565, ..., -0.80111482,
#          0.27745527, -0.87689007],
#        [ 0.07179886,  0.06258867, -0.32928826, ..., -0.22568996,
#          0.75173779, -0.55736699],
#        [ 0.35948586,  0.41556937, -1.54691148, ..., -0.30764555,
#         -0.03873307, -0.76711645]])

# %%
pca = PCA(.95)

# %%
pca_features = pca.fit_transform(features)

# %%
pca_features.shape
# Out:
# (1000, 87)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.26992662, 0.13110536, 0.09426305, 0.05329738, 0.03290378,
#        0.02665315, 0.02233839, 0.02025116, 0.01677624, 0.01497256,
#        0.01380511, 0.01270019, 0.01202518, 0.01116423, 0.01075767,
#        0.01030572, 0.00969392, 0.00906464, 0.00890573, 0.00834963,
#        0.00814512, 0.00726971, 0.00710307, 0.00627901, 0.00587766,
#        0.00536285, 0.00531144, 0.0044169 , 0.00432281, 0.00401634,
#        0.00379145, 0.00376937, 0.00354226, 0.00338395, 0.00331508,
#        0.00305128, 0.00298632, 0.0029331 , 0.00289463, 0.00273267,
#        0.00260203, 0.0025245 , 0.00238876, 0.00237809, 0.00234242,
#        0.00223561, 0.00210452, 0.00205541, 0.00200826, 0.00197705,
#        0.00188601, 0.00186142, 0.0018079 , 0.00173281, 0.00171962,
#        0.00168386, 0.00165793, 0.00156645, 0.00153135, 0.00151449,
#        0.00148794, 0.00147309, 0.00144488, 0.00140907, 0.00137289,
#        0.0013255 , 0.00132163, 0.00128631, 0.00125408, 0.00121851,
#        0.0012053 , 0.00118494, 0.00116694, 0.00111609, 0.00109836,
#        0.00108807, 0.00105366, 0.00104627, 0.00102802, 0.00101046,
#        0.00098335, 0.00095559, 0.00093894, 0.0009326 , 0.00091797,
#        0.00090214, 0.00089128])
